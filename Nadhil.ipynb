# %%
print("||Program Kasir Restoran Wekdi||")
nama= input("Masukkan Nama pemesan: ")
print ("Nama Pemesan:", nama)

print ("")
print ("Menu Makanan")
def pilihan(i):
    switcher={1:'Ayam Goreng',
              2:'Kentang Goreng',
              3:'Burger',
              4:'Nasi'}
    return switcher.get(i,'Masukkan Pilihan!!!')
print("1. Ayam Goreng")
print("2. Kentang Goreng")
print("3. Burger")
print("4. Nasi")
nomor=int(input("Masukkan Pilihan: "))
c=pilihan (nomor)
print (c)

x=0
y=0
jenis1=""
jenis2=""
porsi1= int(input("Berapa Porsi: "))
if nomor==1:
    x=x+porsi1*13000
    print ("Total Harga Makanan = Rp.", x)
    jenis1=("Ayam Goreng")
elif nomor==2:
    x=x+porsi1*9000
    print ("Total Harga Makanan = Rp.", x)
    jenis1=("Kentang Goreng")
elif nomor==3:
    x=x+porsi1*15000
    print ("Total Harga Makanan = Rp.", x)
    jenis1=("Burger")
elif nomor==4:
    x=x+porsi1*6000
    print ("Total Harga Makanan = Rp.", x)
    jenis1=("Nasi")

print("")
print("Menu Minuman")
def pilihan(i):
    switcher={1:'Es Teh Lemon',
              2:'Koka Kola',
              3:'Panta',
              4:'Kopee'}
    return switcher.get(i,'Masukkan Pilihan!!!')
print("1.Es Teh Lemon")
print("2.Koka Kola")
print("3.Panta")
print("4.Kopee")
nomor=int(input("Masukkan Pilihan: "))
c=pilihan(nomor)
print(c)

porsi2=int(input("Berapa Gelas: "))
if nomor==1:
    y=y+porsi2*5000
    print ("Total Harga Minuman = Rp.", y)
    jenis2=("Es Teh Lemon")
elif nomor==2:
    y=y+porsi2*7000
    print ("Total Harga Minuman = Rp.", y)
    jenis2=("Koka Kola")
elif nomor==3:
    y=y+porsi2*7000
    print ("Total Harga Minuman = Rp.", y)
    jenis2=("Panta")
elif nomor==4:
    y=y+porsi2*6000
    print ("Total Harga Minuman = Rp.", y)
    jenis2=("Kopee")

    
z=x+y
print ("\nTotal Pesanan = Rp.", z)
uang=int(input("\nUang Tunai: Rp."))
    
print("\n---------------------------------------")
print("-------------- S T R U K ---------------")
print("----------------------------------------")
print ("--------- Nama      :",nama)
print ("--------- Beli      :",porsi1,jenis1)
print ("---------            ",porsi2,jenis2)
print ("--------- Tagihan   :Rp.",z)
print ("--------- Uang      :Rp.",uang)
akhir=int(uang-z)
print ("--------- Kembalian :Rp.",akhir)
print("----------------------------------------")
print("----------------------------------------")
